# %%
import csv
from faker import Faker
import random
from datetime import datetime, timedelta
import numpy as np
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Using Faker to Augment Data

# %%
#Initialize Faker
fake=Faker()

# %%
#Input and Output Files
input_file='Expense Data.csv' #Original file with 5 entries
output_file='augmented_expense.csv' #Output file with augmented data

# %%
#Load existing data
with open(input_file, 'r') as file:
    reader=csv.reader(file)
    rows=list(reader)

# %%
#Extract header and data rows
header=rows[0]
base_data=rows[1:]

# %%
#Generate new data using faker
new_data=[]
for _ in range(1000):     #Generate 1000 new rows
    base_row=random.choice(base_data)    #Randomly pick an existing row as a abse   
    
    #Generate a fake data around the existing one
    original_date=datetime.strptime(base_row[0], '%Y-%m-%d')
    random_days=random.randint(-30,30)  #+/- 30 days
    new_date=original_date + timedelta(days=random_days)
    
    #Generate fake amount around the base amount
    base_amount=float(base_row[1])
    amount_variation=round(random.uniform(-10,10), 2) #Vary by +/- $10
    new_amount=max(1.0, base_amount + amount_variation)     #Ensure positive
    
    
    #Use the same category and payment method
    category=base_row[2]
    payment_method=base_row[3]
    
    #Generate a fake description
    new_description=fake.sentence(nb_words=5) if random.random() > 0.5 else base_row[4]
    
    #Add the new row to the dataset
    new_data.append([new_date.strftime('%Y-%m-%d'),f"{new_amount:.2f}",category,payment_method,new_description])

# %%
#Write the augmented data to a new csv file
with open (output_file, 'w', newline="") as file:
    writer=csv.writer(file)
    writer.writerow(header)       #Write the header
    writer.writerows(new_data)    #Write the generated data

print(f"Augmented dataset created as '{output_file}'.")
# Out:
# Augmented dataset created as 'augmented_expense.csv'.

# %%
df=pd.read_csv("augmented_expense.csv")
df.head()
# Out:
#          Data  Amount     Category Payment Method  \
# 0  2023-12-27  191.16    Utilities  Bank transfer
# 1  2024-01-21  126.78    Transport     Dedit card
# 2  2024-01-24  117.58    Transport     Dedit card
# 3  2024-01-24   82.49  Health care    Credit card
# 4  2024-02-02   83.73  Health care    Credit card
#
#                                      Description
# 0  Although sometimes tell current should agree.
# 1                          Give senior for seat.
# 2                               Monthly bus pass
# 3    Early pull himself street form real course.
# 4                                 Pharmacy visit

# %% [markdown]
# ## Setup the Database

# %%
#Connect SQLite 
connection = sqlite3.connect('expense.db')

#Create a cursor to execute sql commands
cursor = connection.cursor()

# %%
#Define the table structure
cursor.execute('''
CREATE TABLE IF NOT EXISTS expense (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    date DATE NOT NULL,
    amount REAL NOT NULL,
    category TEXT NOT NULL,
    payment_method TEXT NOT NULL,
    description TEXT
)
''')

#Commit changes and close the connection
connection.commit()
connection.close()

print('Database and table created successfully!')
# Out:
# Database and table created successfully!

# %% [markdown]
# ## Load the CSV Data into Database

# %%
#File paths
csv_file='augmented_expense.csv'
database_file='expense.db'

# %%
#Connect to the sqlite database
connection=sqlite3.connect(database_file)
cursor=connection.cursor()

# %%
#Open csv file and load data
with open (csv_file, 'r') as file:
    reader=csv.DictReader(file)      #Read CSV as dictionary
    for row in reader:                #Insert each row into the table
        cursor.execute('''
        INSERT INTO expense (date,amount,category,payment_method,description)
        VALUES (?,?,?,?,?)
        ''', (row['Data'], row['Amount'], row['Category'], row['Payment Method'], row['Description']))

#Commit changes and close the connection
connection.commit()
connection.close()

print('Data loaded into the database successfully!')
# Out:
# Data loaded into the database successfully!

# %% [markdown]
# ## Test Database

# %%
#Connect to the database
connection=sqlite3.connect('expense.db')
cursor=connection.cursor()

#Query the first 5 rows
cursor.execute('SELECT * FROM expense LIMIT 5')
rows=cursor.fetchall()

#Print the results
for row in rows:
    print(row)
    
#Close the connection
#connection.close()
# Out:
# (1, '2023-12-27', 191.16, 'Utilities', 'Bank transfer', 'Although sometimes tell current should agree.')
# (2, '2024-01-21', 126.78, 'Transport', 'Dedit card', 'Give senior for seat.')
# (3, '2024-01-24', 117.58, 'Transport', 'Dedit card', 'Monthly bus pass')
# (4, '2024-01-24', 82.49, 'Health care', 'Credit card', 'Early pull himself street form real course.')
# (5, '2024-02-02', 83.73, 'Health care', 'Credit card', 'Pharmacy visit')

# %% [markdown]
# # Perform SQL Queries on Database

# %% [markdown]
# ## Basic Queries
#   ### 1. View All Data

# %%
cursor.execute("SELECT * FROM expense")
rows=cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, '2023-12-27', 191.16, 'Utilities', 'Bank transfer', 'Although sometimes tell current should agree.')
# (2, '2024-01-21', 126.78, 'Transport', 'Dedit card', 'Give senior for seat.')
# (3, '2024-01-24', 117.58, 'Transport', 'Dedit card', 'Monthly bus pass')
# (4, '2024-01-24', 82.49, 'Health care', 'Credit card', 'Early pull himself street form real course.')
# (5, '2024-02-02', 83.73, 'Health care', 'Credit card', 'Pharmacy visit')
# (6, '2024-01-03', 66.63, 'Health care', 'Credit card', 'Mind traditional leave another result only.')
# (7, '2024-01-01', 57.46, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (8, '2024-01-12', 196.71, 'Utilities', 'Bank transfer', 'Electricity bill')
# (9, '2024-01-11', 195.37, 'Utilities', 'Bank transfer', 'Rock often record owner along benefit.')
# (10, '2024-02-04', 77.86, 'Health care', 'Credit card', 'Pharmacy visit')
# (11, '2024-01-24', 54.84, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (12, '2024-01-11', 113.31, 'Transport', 'Dedit card', 'Light participant next decide open.')
# (13, '2023-12-25', 207.84, 'Utilities', 'Bank transfer', 'Electricity bill')
# (14, '2024-01-10', 55.95, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (15, '2024-01-02', 209.39, 'Utilities', 'Bank transfer', 'Electricity bill')
# (16, '2024-01-08', 70.93, 'Health care', 'Credit card', 'Free sell price exist end.')
# (17, '2024-01-01', 33.98, 'Entertainment', 'Cash', 'Finally education cover radio option.')
# (18, '2023-12-16', 121.53, 'Transport', 'Dedit card', 'Prevent possible song daughter sense hundred.')
# (19, '2023-12-08', 41.59, 'Groceries', 'Credit card', 'Happen boy write top leader hour.')
# (20, '2023-12-19', 69.94, 'Health care', 'Credit card', 'Pharmacy visit')
# (21, '2023-12-24', 123.2, 'Transport', 'Dedit card', 'Monthly bus pass')
# (22, '2023-12-22', 199.28, 'Utilities', 'Bank transfer', 'Electricity bill')
# (23, '2023-12-19', 43.59, 'Groceries', 'Credit card', 'Organization shoulder carry.')
# (24, '2024-02-03', 205.45, 'Utilities', 'Bank transfer', 'Electricity bill')
# (25, '2023-12-08', 56.36, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (26, '2024-01-24', 192.29, 'Utilities', 'Bank transfer', 'Never wall summer deep decision throughout compare.')
# (27, '2023-12-15', 56.13, 'Groceries', 'Credit card', 'On avoid authority.')
# (28, '2023-12-17', 46.66, 'Groceries', 'Credit card', 'Do stuff color become.')
# (29, '2024-01-30', 203.75, 'Utilities', 'Bank transfer', 'Electricity bill')
# (30, '2024-01-20', 200.99, 'Utilities', 'Bank transfer', 'Electricity bill')
# (31, '2023-12-30', 115.46, 'Transport', 'Dedit card', 'Monthly bus pass')
# (32, '2023-12-04', 40.4, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (33, '2023-12-06', 125.34, 'Transport', 'Dedit card', 'Claim pretty choose remain money office.')
# (34, '2024-01-31', 25.37, 'Entertainment', 'Cash', 'Movie night')
# (35, '2024-01-31', 120.89, 'Transport', 'Dedit card', 'Monthly bus pass')
# (36, '2023-12-10', 117.01, 'Transport', 'Dedit card', 'Physical fight population so politics fly.')
# (37, '2023-12-13', 49.4, 'Groceries', 'Credit card', 'While number start score.')
# (38, '2024-01-24', 191.38, 'Utilities', 'Bank transfer', 'Electricity bill')
# (39, '2023-12-16', 121.47, 'Transport', 'Dedit card', 'Monthly bus pass')
# (40, '2024-02-01', 207.77, 'Utilities', 'Bank transfer', 'Product gas line evidence crime.')
# (41, '2023-12-24', 118.93, 'Transport', 'Dedit card', 'Monthly bus pass')
# (42, '2023-12-19', 199.03, 'Utilities', 'Bank transfer', 'Respond current everybody answer no trial.')
# (43, '2023-12-31', 38.95, 'Entertainment', 'Cash', 'Movie night')
# (44, '2024-01-25', 52.97, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (45, '2023-12-17', 70.26, 'Health care', 'Credit card', 'About minute international list only.')
# (46, '2024-01-08', 73.52, 'Health care', 'Credit card', 'War popular pressure various.')
# (47, '2024-01-10', 208.36, 'Utilities', 'Bank transfer', 'Electricity bill')
# (48, '2023-12-21', 72.6, 'Health care', 'Credit card', 'Order they take outside.')
# (49, '2024-01-28', 121.76, 'Transport', 'Dedit card', 'Monthly bus pass')
# (50, '2024-01-29', 75.63, 'Health care', 'Credit card', 'Pharmacy visit')
# (51, '2023-12-19', 39.62, 'Entertainment', 'Cash', 'Movie night')
# (52, '2023-12-21', 28.97, 'Entertainment', 'Cash', 'Movie night')
# (53, '2023-12-24', 120.17, 'Transport', 'Dedit card', 'Pressure which tell anything.')
# (54, '2024-01-11', 121.19, 'Transport', 'Dedit card', 'See actually second short leg.')
# (55, '2023-12-30', 47.96, 'Groceries', 'Credit card', 'Wrong wish beyond.')
# (56, '2023-12-11', 55.9, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (57, '2023-12-11', 55.03, 'Groceries', 'Credit card', 'Race collection yet air.')
# (58, '2023-12-29', 68.72, 'Health care', 'Credit card', 'Pharmacy visit')
# (59, '2024-02-01', 21.42, 'Entertainment', 'Cash', 'Eat top health.')
# (60, '2024-01-28', 198.67, 'Utilities', 'Bank transfer', 'Number several blood world.')
# (61, '2023-12-05', 195.41, 'Utilities', 'Bank transfer', 'Image they safe indeed.')
# (62, '2024-02-01', 31.63, 'Entertainment', 'Cash', 'Tell life help federal.')
# (63, '2023-12-27', 39.07, 'Entertainment', 'Cash', 'Movie night')
# (64, '2023-12-04', 113.08, 'Transport', 'Dedit card', 'Monthly bus pass')
# (65, '2023-12-15', 43.31, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (66, '2024-01-31', 65.07, 'Health care', 'Credit card', 'Pharmacy visit')
# (67, '2023-12-26', 191.72, 'Utilities', 'Bank transfer', 'Loss heart itself soldier.')
# (68, '2024-01-13', 195.93, 'Utilities', 'Bank transfer', 'Control fill again bank prevent serve.')
# (69, '2023-12-20', 54.57, 'Groceries', 'Credit card', 'Lot design produce week either.')
# (70, '2023-12-12', 42.67, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (71, '2024-01-14', 59.98, 'Groceries', 'Credit card', 'Her board radio up.')
# (72, '2023-12-11', 37.45, 'Entertainment', 'Cash', 'Movie night')
# (73, '2023-12-27', 124.78, 'Transport', 'Dedit card', 'Monthly bus pass')
# (74, '2023-12-20', 57.09, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (75, '2023-12-15', 37.76, 'Entertainment', 'Cash', 'Bill lay enough.')
# (76, '2024-01-26', 53.29, 'Groceries', 'Credit card', 'High occur follow.')
# (77, '2023-12-04', 51.72, 'Groceries', 'Credit card', 'Film white develop painting.')
# (78, '2024-01-01', 113.29, 'Transport', 'Dedit card', 'Monthly bus pass')
# (79, '2024-01-01', 22.66, 'Entertainment', 'Cash', 'Property prove tree story travel.')
# (80, '2023-12-30', 192.48, 'Utilities', 'Bank transfer', 'Yes statement opportunity.')
# (81, '2023-12-26', 57.39, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (82, '2023-12-14', 36.51, 'Entertainment', 'Cash', 'Home low lot store.')
# (83, '2023-12-09', 36.91, 'Entertainment', 'Cash', 'Movie night')
# (84, '2023-12-08', 26.44, 'Entertainment', 'Cash', 'Movie night')
# (85, '2024-01-05', 50.47, 'Groceries', 'Credit card', 'Church public couple example information whose.')
# (86, '2023-12-09', 47.97, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (87, '2024-01-07', 27.88, 'Entertainment', 'Cash', 'Movie night')
# (88, '2024-01-03', 27.07, 'Entertainment', 'Cash', 'Movie night')
# (89, '2023-12-29', 195.5, 'Utilities', 'Bank transfer', 'Avoid environment speak free rich culture.')
# (90, '2024-01-14', 112.67, 'Transport', 'Dedit card', 'When campaign into issue teach involve.')
# (91, '2024-01-19', 207.16, 'Utilities', 'Bank transfer', 'Electricity bill')
# (92, '2023-12-16', 77.62, 'Health care', 'Credit card', 'Pharmacy visit')
# (93, '2024-02-04', 71.08, 'Health care', 'Credit card', 'While reduce difference look type.')
# (94, '2023-12-07', 121.98, 'Transport', 'Dedit card', 'Visit benefit benefit parent their source.')
# (95, '2024-01-25', 119.3, 'Transport', 'Dedit card', 'Monthly bus pass')
# (96, '2024-01-28', 76.67, 'Health care', 'Credit card', 'Pharmacy visit')
# (97, '2024-01-08', 120.13, 'Transport', 'Dedit card', 'Agent long picture nature matter.')
# (98, '2024-01-28', 27.42, 'Entertainment', 'Cash', 'If event better.')
# (99, '2023-12-07', 59.76, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (100, '2023-12-21', 20.88, 'Entertainment', 'Cash', 'Movie night')
# (101, '2023-12-04', 110.09, 'Transport', 'Dedit card', 'Process rock couple.')
# (102, '2023-12-24', 50.53, 'Groceries', 'Credit card', 'However base worry week.')
# (103, '2024-01-25', 123.45, 'Transport', 'Dedit card', 'Monthly bus pass')
# (104, '2024-02-01', 118.46, 'Transport', 'Dedit card', 'Monthly bus pass')
# (105, '2024-01-09', 121.72, 'Transport', 'Dedit card', 'Thousand back best great until me.')
# (106, '2024-01-20', 208.32, 'Utilities', 'Bank transfer', 'Federal specific beautiful.')
# (107, '2023-12-06', 29.47, 'Entertainment', 'Cash', 'Federal blue save tax tend.')
# (108, '2023-12-26', 119.91, 'Transport', 'Dedit card', 'Spend along year sometimes.')
# (109, '2023-12-05', 120.47, 'Transport', 'Dedit card', 'Would such again same fight believe.')
# (110, '2024-01-11', 44.23, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (111, '2023-12-12', 39.29, 'Entertainment', 'Cash', 'Movie night')
# (112, '2024-01-27', 29.82, 'Entertainment', 'Cash', 'Major scene have.')
# (113, '2024-01-30', 122.86, 'Transport', 'Dedit card', 'Monthly bus pass')
# (114, '2023-12-28', 126.71, 'Transport', 'Dedit card', 'Difficult office computer.')
# (115, '2024-01-04', 82.23, 'Health care', 'Credit card', 'Pharmacy visit')
# (116, '2024-01-15', 82.34, 'Health care', 'Credit card', 'Long we yes.')
# (117, '2023-12-27', 75.08, 'Health care', 'Credit card', 'Pharmacy visit')
# (118, '2024-01-21', 208.02, 'Utilities', 'Bank transfer', 'Consider policy its cut soldier little.')
# (119, '2023-12-28', 74.14, 'Health care', 'Credit card', 'Pharmacy visit')
# (120, '2023-12-19', 129.99, 'Transport', 'Dedit card', 'Blood heart follow.')
# (121, '2024-01-07', 72.0, 'Health care', 'Credit card', 'Pharmacy visit')
# (122, '2024-01-25', 118.89, 'Transport', 'Dedit card', 'Large time alone level nature.')
# (123, '2024-01-25', 119.18, 'Transport', 'Dedit card', 'Monthly bus pass')
# (124, '2024-01-10', 45.5, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (125, '2023-12-14', 83.27, 'Health care', 'Credit card', 'Against senior off case paper.')
# (126, '2023-12-07', 33.83, 'Entertainment', 'Cash', 'Raise behind want teach.')
# (127, '2023-12-18', 207.56, 'Utilities', 'Bank transfer', 'Electricity bill')
# (128, '2023-12-05', 117.1, 'Transport', 'Dedit card', 'Monthly bus pass')
# (129, '2024-01-24', 208.28, 'Utilities', 'Bank transfer', 'Nor especially building whatever offer.')
# (130, '2023-12-29', 38.11, 'Entertainment', 'Cash', 'Project never play.')
# (131, '2023-12-17', 44.47, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (132, '2024-01-18', 69.96, 'Health care', 'Credit card', 'Wear west similar interview I.')
# (133, '2023-12-19', 123.36, 'Transport', 'Dedit card', 'Monthly bus pass')
# (134, '2024-01-03', 129.71, 'Transport', 'Dedit card', 'Fill south quality.')
# (135, '2024-01-22', 35.05, 'Entertainment', 'Cash', 'Design plan store ten two not.')
# (136, '2024-01-21', 126.23, 'Transport', 'Dedit card', 'Monthly bus pass')
# (137, '2023-12-04', 119.81, 'Transport', 'Dedit card', 'Monthly bus pass')
# (138, '2024-01-17', 120.18, 'Transport', 'Dedit card', 'Spring specific become force.')
# (139, '2023-12-04', 54.86, 'Groceries', 'Credit card', 'Mention party may day star.')
# (140, '2023-12-31', 82.96, 'Health care', 'Credit card', 'Pharmacy visit')
# (141, '2023-12-11', 78.73, 'Health care', 'Credit card', 'Pharmacy visit')
# (142, '2024-01-19', 59.98, 'Groceries', 'Credit card', 'Important would lose figure road.')
# (143, '2023-12-09', 55.91, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (144, '2023-12-08', 33.5, 'Entertainment', 'Cash', 'Want eight daughter room.')
# (145, '2024-01-17', 49.14, 'Groceries', 'Credit card', 'Area soon before million.')
# (146, '2024-01-01', 207.67, 'Utilities', 'Bank transfer', 'Electricity bill')
# (147, '2023-12-20', 70.39, 'Health care', 'Credit card', 'Pharmacy visit')
# (148, '2024-01-04', 120.94, 'Transport', 'Dedit card', 'Capital another support once reality American.')
# (149, '2024-01-11', 49.46, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (150, '2024-01-14', 73.19, 'Health care', 'Credit card', 'Firm language money.')
# (151, '2024-01-18', 41.89, 'Groceries', 'Credit card', 'Cultural its although hope issue.')
# (152, '2024-01-23', 203.57, 'Utilities', 'Bank transfer', 'Electricity bill')
# (153, '2023-12-30', 28.35, 'Entertainment', 'Cash', 'Movie night')
# (154, '2023-12-18', 196.67, 'Utilities', 'Bank transfer', 'Electricity bill')
# (155, '2024-01-01', 208.23, 'Utilities', 'Bank transfer', 'Electricity bill')
# (156, '2023-12-19', 37.23, 'Entertainment', 'Cash', 'Movie night')
# (157, '2024-01-07', 192.3, 'Utilities', 'Bank transfer', 'Electricity bill')
# (158, '2024-01-12', 41.12, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (159, '2023-12-07', 78.91, 'Health care', 'Credit card', 'Reach future front bag technology.')
# (160, '2024-01-26', 54.25, 'Groceries', 'Credit card', 'City agreement these job.')
# (161, '2023-12-06', 35.64, 'Entertainment', 'Cash', 'Movie night')
# (162, '2023-12-05', 59.34, 'Groceries', 'Credit card', 'Method deal director.')
# (163, '2024-01-31', 121.99, 'Transport', 'Dedit card', 'Able though turn newspaper finish final.')
# (164, '2023-12-17', 200.01, 'Utilities', 'Bank transfer', 'Electricity bill')
# (165, '2024-01-04', 112.95, 'Transport', 'Dedit card', 'Monthly bus pass')
# (166, '2023-12-29', 55.2, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (167, '2024-01-13', 204.97, 'Utilities', 'Bank transfer', 'Electricity bill')
# (168, '2023-12-28', 194.15, 'Utilities', 'Bank transfer', 'Electricity bill')
# (169, '2024-01-31', 129.9, 'Transport', 'Dedit card', 'Position computer wonder.')
# (170, '2023-12-13', 195.23, 'Utilities', 'Bank transfer', 'Health perhaps us fill send PM.')
# (171, '2023-12-27', 120.15, 'Transport', 'Dedit card', 'Whom add everything account inside feeling.')
# (172, '2023-12-18', 29.56, 'Entertainment', 'Cash', 'Movie night')
# (173, '2023-12-04', 117.72, 'Transport', 'Dedit card', 'Monthly bus pass')
# (174, '2023-12-20', 207.13, 'Utilities', 'Bank transfer', 'Electricity bill')
# (175, '2023-12-05', 37.18, 'Entertainment', 'Cash', 'Loss traditional image worry know.')
# (176, '2024-01-25', 82.21, 'Health care', 'Credit card', 'Pharmacy visit')
# (177, '2024-01-13', 114.3, 'Transport', 'Dedit card', 'Monthly bus pass')
# (178, '2024-01-28', 110.45, 'Transport', 'Dedit card', 'Monthly bus pass')
# (179, '2024-01-24', 45.54, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (180, '2023-12-09', 55.08, 'Groceries', 'Credit card', 'Show word vote role wall.')
# (181, '2023-12-16', 207.29, 'Utilities', 'Bank transfer', 'Process both house.')
# (182, '2024-01-13', 72.62, 'Health care', 'Credit card', 'Grow let wrong main good great.')
# (183, '2024-01-20', 120.51, 'Transport', 'Dedit card', 'Become PM far value them hit.')
# (184, '2023-12-20', 58.23, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (185, '2024-01-15', 205.75, 'Utilities', 'Bank transfer', 'Claim knowledge forward.')
# (186, '2024-01-24', 46.81, 'Groceries', 'Credit card', 'Us thank quickly realize after.')
# (187, '2023-12-28', 83.26, 'Health care', 'Credit card', 'Pharmacy visit')
# (188, '2023-12-22', 198.6, 'Utilities', 'Bank transfer', 'Garden win imagine big wife.')
# (189, '2024-01-06', 196.29, 'Utilities', 'Bank transfer', 'Capital fact then ahead.')
# (190, '2023-12-09', 36.72, 'Entertainment', 'Cash', 'Movie night')
# (191, '2023-12-22', 200.96, 'Utilities', 'Bank transfer', 'Electricity bill')
# (192, '2024-01-27', 119.43, 'Transport', 'Dedit card', 'Monthly bus pass')
# (193, '2023-12-07', 190.47, 'Utilities', 'Bank transfer', 'Majority two loss.')
# (194, '2024-01-14', 195.87, 'Utilities', 'Bank transfer', 'Fast class list.')
# (195, '2024-01-30', 22.0, 'Entertainment', 'Cash', 'Movie night')
# (196, '2024-02-01', 208.05, 'Utilities', 'Bank transfer', 'A wear clearly.')
# (197, '2024-01-29', 75.59, 'Health care', 'Credit card', 'Pharmacy visit')
# (198, '2024-01-01', 68.69, 'Health care', 'Credit card', 'Pharmacy visit')
# (199, '2024-01-25', 190.5, 'Utilities', 'Bank transfer', 'Couple suggest season however outside.')
# (200, '2023-12-18', 194.03, 'Utilities', 'Bank transfer', 'Certainly push inside.')
# (201, '2023-12-13', 81.77, 'Health care', 'Credit card', 'Station test gun program too.')
# (202, '2024-01-16', 54.69, 'Groceries', 'Credit card', 'Some newspaper consumer organization really.')
# (203, '2023-12-10', 24.73, 'Entertainment', 'Cash', 'Movie night')
# (204, '2023-12-28', 203.4, 'Utilities', 'Bank transfer', 'Without environmental bag quite radio carry.')
# (205, '2024-01-24', 79.82, 'Health care', 'Credit card', 'Card discover senior.')
# (206, '2023-12-11', 207.25, 'Utilities', 'Bank transfer', 'Appear art great gun.')
# (207, '2023-12-16', 80.4, 'Health care', 'Credit card', 'Behind subject minute phone window.')
# (208, '2023-12-31', 123.04, 'Transport', 'Dedit card', 'Monthly bus pass')
# (209, '2023-12-26', 127.98, 'Transport', 'Dedit card', 'Monthly bus pass')
# (210, '2023-12-08', 203.53, 'Utilities', 'Bank transfer', 'Electricity bill')
# (211, '2023-12-06', 74.29, 'Health care', 'Credit card', 'Pharmacy visit')
# (212, '2024-01-27', 43.89, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (213, '2024-01-06', 26.07, 'Entertainment', 'Cash', 'Together about but perhaps billion stage.')
# (214, '2024-01-17', 23.7, 'Entertainment', 'Cash', 'Movie night')
# (215, '2023-12-17', 200.79, 'Utilities', 'Bank transfer', 'Official never social environmental.')
# (216, '2023-12-17', 34.41, 'Entertainment', 'Cash', 'Nation seek heart.')
# (217, '2023-12-08', 74.3, 'Health care', 'Credit card', 'Pharmacy visit')
# (218, '2024-01-22', 82.72, 'Health care', 'Credit card', 'Own per score question.')
# (219, '2023-12-08', 33.68, 'Entertainment', 'Cash', 'Cover human low.')
# (220, '2024-01-18', 194.24, 'Utilities', 'Bank transfer', 'Electricity bill')
# (221, '2024-01-08', 49.41, 'Groceries', 'Credit card', 'Order store anyone performance.')
# (222, '2024-01-19', 81.44, 'Health care', 'Credit card', 'Opportunity staff shoulder.')
# (223, '2023-12-27', 38.35, 'Entertainment', 'Cash', 'Movie night')
# (224, '2023-12-30', 110.5, 'Transport', 'Dedit card', 'Entire air hand rich.')
# (225, '2024-01-20', 48.1, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (226, '2023-12-13', 26.42, 'Entertainment', 'Cash', 'Movie night')
# (227, '2023-12-30', 81.35, 'Health care', 'Credit card', 'Pharmacy visit')
# (228, '2024-01-16', 32.2, 'Entertainment', 'Cash', 'Appear dinner suffer data cut once.')
# (229, '2024-01-21', 24.17, 'Entertainment', 'Cash', 'Role college throw you eye box.')
# (230, '2024-01-25', 48.33, 'Groceries', 'Credit card', 'No task believe performance inside.')
# (231, '2023-12-15', 54.81, 'Groceries', 'Credit card', 'Guess run anything dark.')
# (232, '2024-01-05', 196.18, 'Utilities', 'Bank transfer', 'Electricity bill')
# (233, '2023-12-12', 42.6, 'Groceries', 'Credit card', 'Both too agree.')
# (234, '2024-01-13', 20.37, 'Entertainment', 'Cash', 'North thank anything get appear north.')
# (235, '2023-12-31', 47.61, 'Groceries', 'Credit card', 'Standard author begin voice.')
# (236, '2023-12-27', 39.16, 'Entertainment', 'Cash', 'Movie night')
# (237, '2023-12-08', 126.49, 'Transport', 'Dedit card', 'Rest rich billion scene hospital your.')
# (238, '2024-01-29', 41.05, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (239, '2024-01-06', 205.26, 'Utilities', 'Bank transfer', 'Electricity bill')
# (240, '2024-01-08', 32.32, 'Entertainment', 'Cash', 'Movie night')
# (241, '2023-12-20', 197.63, 'Utilities', 'Bank transfer', 'Electricity bill')
# (242, '2024-01-12', 114.75, 'Transport', 'Dedit card', 'About myself red.')
# (243, '2023-12-21', 38.3, 'Entertainment', 'Cash', 'Wind smile available.')
# (244, '2023-12-19', 49.64, 'Groceries', 'Credit card', 'Feeling dream too public child concern.')
# (245, '2023-12-09', 44.46, 'Groceries', 'Credit card', 'Oil then read miss.')
# (246, '2023-12-15', 67.6, 'Health care', 'Credit card', 'Pharmacy visit')
# (247, '2023-12-21', 57.98, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (248, '2023-12-15', 21.85, 'Entertainment', 'Cash', 'Movie night')
# (249, '2023-12-27', 201.5, 'Utilities', 'Bank transfer', 'My apply many best later.')
# (250, '2023-12-09', 76.15, 'Health care', 'Credit card', 'Pharmacy visit')
# (251, '2024-01-19', 21.98, 'Entertainment', 'Cash', 'Against property kind line relate money.')
# (252, '2024-01-19', 203.81, 'Utilities', 'Bank transfer', 'Physical talk whom.')
# (253, '2023-12-29', 200.39, 'Utilities', 'Bank transfer', 'Electricity bill')
# (254, '2024-01-23', 120.18, 'Transport', 'Dedit card', 'Board stand participant good property.')
# (255, '2024-01-03', 116.99, 'Transport', 'Dedit card', 'Team short major spend.')
# (256, '2024-01-18', 59.46, 'Groceries', 'Credit card', 'Too religious customer physical rest.')
# (257, '2024-01-18', 30.43, 'Entertainment', 'Cash', 'Movie night')
# (258, '2023-12-09', 78.53, 'Health care', 'Credit card', 'Identify smile project.')
# (259, '2023-12-31', 21.31, 'Entertainment', 'Cash', 'Movie night')
# (260, '2023-12-16', 50.09, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (261, '2024-01-22', 205.73, 'Utilities', 'Bank transfer', 'Electricity bill')
# (262, '2023-12-24', 114.52, 'Transport', 'Dedit card', 'Monthly bus pass')
# (263, '2024-01-16', 199.01, 'Utilities', 'Bank transfer', 'Decade treat majority.')
# (264, '2024-01-30', 195.26, 'Utilities', 'Bank transfer', 'Fly black pull.')
# (265, '2024-01-18', 202.71, 'Utilities', 'Bank transfer', 'Electricity bill')
# (266, '2023-12-30', 65.09, 'Health care', 'Credit card', 'Serve address safe case second yeah.')
# (267, '2023-12-14', 119.7, 'Transport', 'Dedit card', 'Two pretty sound pattern up.')
# (268, '2024-01-30', 111.05, 'Transport', 'Dedit card', 'Speech tree fly authority push.')
# (269, '2023-12-29', 53.11, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (270, '2024-01-03', 200.27, 'Utilities', 'Bank transfer', 'Major stand own mission half.')
# (271, '2023-12-25', 41.41, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (272, '2024-01-17', 195.66, 'Utilities', 'Bank transfer', 'Electricity bill')
# (273, '2024-01-17', 41.4, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (274, '2023-12-11', 40.06, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (275, '2023-12-24', 41.86, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (276, '2024-01-17', 59.54, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (277, '2023-12-25', 126.5, 'Transport', 'Dedit card', 'Home together describe.')
# (278, '2023-12-18', 20.16, 'Entertainment', 'Cash', 'Movie night')
# (279, '2024-01-23', 37.01, 'Entertainment', 'Cash', 'Movie night')
# (280, '2023-12-13', 25.12, 'Entertainment', 'Cash', 'Movie night')
# (281, '2024-01-03', 43.03, 'Groceries', 'Credit card', 'Method occur concern drive.')
# (282, '2024-01-11', 205.17, 'Utilities', 'Bank transfer', 'Near while candidate.')
# (283, '2024-01-30', 207.43, 'Utilities', 'Bank transfer', 'Prove hair organization drop over far.')
# (284, '2024-01-27', 196.96, 'Utilities', 'Bank transfer', 'Electricity bill')
# (285, '2024-01-24', 116.94, 'Transport', 'Dedit card', 'Value rate question unit forget win.')
# (286, '2023-12-13', 67.19, 'Health care', 'Credit card', 'You visit dog.')
# (287, '2024-01-27', 78.1, 'Health care', 'Credit card', 'Local short difficult.')
# (288, '2023-12-22', 202.28, 'Utilities', 'Bank transfer', 'Reason year piece accept two.')
# (289, '2023-12-14', 34.95, 'Entertainment', 'Cash', 'Movie night')
# (290, '2024-01-01', 49.85, 'Groceries', 'Credit card', 'Some president note result consider.')
# (291, '2023-12-09', 67.01, 'Health care', 'Credit card', 'Pharmacy visit')
# (292, '2023-12-15', 32.77, 'Entertainment', 'Cash', 'Opportunity across training.')
# (293, '2023-12-20', 73.32, 'Health care', 'Credit card', 'Pharmacy visit')
# (294, '2024-01-13', 22.9, 'Entertainment', 'Cash', 'Movie night')
# (295, '2023-12-06', 119.76, 'Transport', 'Dedit card', 'Monthly bus pass')
# (296, '2023-12-16', 46.27, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (297, '2023-12-21', 20.64, 'Entertainment', 'Cash', 'Movie night')
# (298, '2024-01-23', 28.33, 'Entertainment', 'Cash', 'Movie night')
# (299, '2024-01-30', 26.35, 'Entertainment', 'Cash', 'Available door certainly.')
# (300, '2023-12-10', 33.26, 'Entertainment', 'Cash', 'Spend various race role class trip.')
# (301, '2024-01-02', 20.68, 'Entertainment', 'Cash', 'Benefit but machine tax let force.')
# (302, '2023-12-21', 208.07, 'Utilities', 'Bank transfer', 'Only throw knowledge daughter nor.')
# (303, '2024-01-25', 39.64, 'Entertainment', 'Cash', 'Tonight outside rise information.')
# (304, '2023-12-13', 194.92, 'Utilities', 'Bank transfer', 'Electricity bill')
# (305, '2024-01-30', 51.42, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (306, '2023-12-18', 123.39, 'Transport', 'Dedit card', 'Monthly bus pass')
# (307, '2023-12-10', 203.51, 'Utilities', 'Bank transfer', 'Electricity bill')
# (308, '2024-01-06', 76.17, 'Health care', 'Credit card', 'Available series both show only simply.')
# (309, '2024-01-03', 207.4, 'Utilities', 'Bank transfer', 'Open song would.')
# (310, '2024-01-02', 204.26, 'Utilities', 'Bank transfer', 'Electricity bill')
# (311, '2024-01-24', 79.68, 'Health care', 'Credit card', 'Pharmacy visit')
# (312, '2024-01-05', 124.12, 'Transport', 'Dedit card', 'Environment standard player.')
# (313, '2024-01-01', 51.12, 'Groceries', 'Credit card', 'His send we but spend will.')
# (314, '2024-01-11', 42.94, 'Groceries', 'Credit card', 'Leg until family.')
# (315, '2024-01-24', 26.9, 'Entertainment', 'Cash', 'Movie night')
# (316, '2024-01-01', 203.74, 'Utilities', 'Bank transfer', 'Electricity bill')
# (317, '2023-12-14', 190.32, 'Utilities', 'Bank transfer', 'Electricity bill')
# (318, '2023-12-29', 78.92, 'Health care', 'Credit card', 'Born politics lot attack quite threat.')
# (319, '2024-01-31', 73.62, 'Health care', 'Credit card', 'Degree join fast.')
# (320, '2023-12-08', 43.92, 'Groceries', 'Credit card', 'Picture theory fly.')
# (321, '2024-01-27', 45.77, 'Groceries', 'Credit card', 'Herself act send moment main.')
# (322, '2024-01-11', 110.26, 'Transport', 'Dedit card', 'Can simply work after Democrat son.')
# (323, '2023-12-21', 25.03, 'Entertainment', 'Cash', 'Movie night')
# (324, '2023-12-16', 42.0, 'Groceries', 'Credit card', 'Sport let level institution fish relationship.')
# (325, '2024-01-06', 20.03, 'Entertainment', 'Cash', 'Movie night')
# (326, '2023-12-30', 79.82, 'Health care', 'Credit card', 'Pharmacy visit')
# (327, '2024-01-11', 128.43, 'Transport', 'Dedit card', 'Drive any affect.')
# (328, '2023-12-16', 202.48, 'Utilities', 'Bank transfer', 'Chance open off.')
# (329, '2023-12-29', 29.06, 'Entertainment', 'Cash', 'Other lot tree manage.')
# (330, '2024-01-09', 42.99, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (331, '2023-12-11', 191.88, 'Utilities', 'Bank transfer', 'So Mrs open.')
# (332, '2024-01-01', 193.43, 'Utilities', 'Bank transfer', 'Electricity bill')
# (333, '2024-01-10', 192.89, 'Utilities', 'Bank transfer', 'Electricity bill')
# (334, '2024-01-22', 79.61, 'Health care', 'Credit card', 'Pharmacy visit')
# (335, '2024-01-27', 76.1, 'Health care', 'Credit card', 'Word clear sea agree.')
# (336, '2023-12-12', 201.61, 'Utilities', 'Bank transfer', 'Will animal sign.')
# (337, '2024-01-26', 66.33, 'Health care', 'Credit card', 'Rather thousand easy.')
# (338, '2023-12-09', 117.92, 'Transport', 'Dedit card', 'Audience state bar.')
# (339, '2023-12-07', 71.05, 'Health care', 'Credit card', 'Future hair most.')
# (340, '2023-12-31', 35.04, 'Entertainment', 'Cash', 'Movie night')
# (341, '2024-01-07', 82.9, 'Health care', 'Credit card', 'Pharmacy visit')
# (342, '2023-12-21', 21.65, 'Entertainment', 'Cash', 'Single performance argue table bad.')
# (343, '2024-01-06', 202.8, 'Utilities', 'Bank transfer', 'Decade century city.')
# (344, '2024-01-08', 209.64, 'Utilities', 'Bank transfer', 'Electricity bill')
# (345, '2024-01-01', 49.66, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (346, '2024-01-17', 22.18, 'Entertainment', 'Cash', 'Movie night')
# (347, '2024-01-11', 121.47, 'Transport', 'Dedit card', 'Another positive small sit.')
# (348, '2024-01-26', 52.73, 'Groceries', 'Credit card', 'State call number exist.')
# (349, '2023-12-08', 110.65, 'Transport', 'Dedit card', 'Monthly bus pass')
# (350, '2023-12-05', 21.01, 'Entertainment', 'Cash', 'Movie night')
# (351, '2024-01-01', 117.11, 'Transport', 'Dedit card', 'Monthly bus pass')
# (352, '2023-12-29', 30.39, 'Entertainment', 'Cash', 'To western letter dog.')
# (353, '2024-01-21', 206.36, 'Utilities', 'Bank transfer', 'Electricity bill')
# (354, '2023-12-06', 30.17, 'Entertainment', 'Cash', 'Give sell former.')
# (355, '2024-01-25', 21.87, 'Entertainment', 'Cash', 'Movie night')
# (356, '2023-12-16', 197.31, 'Utilities', 'Bank transfer', 'Police those central number.')
# (357, '2023-12-08', 206.37, 'Utilities', 'Bank transfer', 'Society government ever.')
# (358, '2023-12-16', 49.39, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (359, '2024-01-26', 67.63, 'Health care', 'Credit card', 'Pharmacy visit')
# (360, '2023-12-31', 196.19, 'Utilities', 'Bank transfer', 'Factor author summer.')
# (361, '2024-02-03', 195.11, 'Utilities', 'Bank transfer', 'Electricity bill')
# (362, '2024-01-30', 26.91, 'Entertainment', 'Cash', 'Movie night')
# (363, '2024-01-10', 110.92, 'Transport', 'Dedit card', 'Monthly bus pass')
# (364, '2024-01-21', 125.88, 'Transport', 'Dedit card', 'Monthly bus pass')
# (365, '2024-01-20', 114.88, 'Transport', 'Dedit card', 'His nice like specific.')
# (366, '2024-01-10', 48.19, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (367, '2023-12-10', 24.4, 'Entertainment', 'Cash', 'Score home about.')
# (368, '2023-12-23', 207.55, 'Utilities', 'Bank transfer', 'Electricity bill')
# (369, '2023-12-26', 41.88, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (370, '2024-01-06', 67.32, 'Health care', 'Credit card', 'Pharmacy visit')
# (371, '2024-01-31', 190.25, 'Utilities', 'Bank transfer', 'Electricity bill')
# (372, '2023-12-10', 118.21, 'Transport', 'Dedit card', 'Test guess season effort in degree.')
# (373, '2024-01-20', 128.63, 'Transport', 'Dedit card', 'Pressure mother listen including pick life.')
# (374, '2024-01-06', 110.23, 'Transport', 'Dedit card', 'Monthly bus pass')
# (375, '2023-12-08', 70.4, 'Health care', 'Credit card', 'Pharmacy visit')
# (376, '2023-12-31', 23.39, 'Entertainment', 'Cash', 'Movie night')
# (377, '2024-01-11', 53.6, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (378, '2024-01-21', 122.66, 'Transport', 'Dedit card', 'Agency land name account.')
# (379, '2023-12-07', 204.46, 'Utilities', 'Bank transfer', 'Involve political on sometimes agreement fund.')
# (380, '2024-01-17', 27.95, 'Entertainment', 'Cash', 'Movie night')
# (381, '2024-01-08', 22.52, 'Entertainment', 'Cash', 'Movie night')
# (382, '2024-02-01', 67.93, 'Health care', 'Credit card', 'Pharmacy visit')
# (383, '2024-01-07', 54.4, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (384, '2024-01-27', 129.63, 'Transport', 'Dedit card', 'Monthly bus pass')
# (385, '2023-12-19', 80.09, 'Health care', 'Credit card', 'Pharmacy visit')
# (386, '2024-01-05', 191.9, 'Utilities', 'Bank transfer', 'Electricity bill')
# (387, '2024-02-02', 190.29, 'Utilities', 'Bank transfer', 'Note morning employee camera cell.')
# (388, '2024-01-06', 29.32, 'Entertainment', 'Cash', 'Movie night')
# (389, '2024-02-03', 78.1, 'Health care', 'Credit card', 'Tv international property.')
# (390, '2023-12-24', 122.76, 'Transport', 'Dedit card', 'Monthly bus pass')
# (391, '2024-01-29', 38.35, 'Entertainment', 'Cash', 'Movie night')
# (392, '2023-12-30', 38.22, 'Entertainment', 'Cash', 'Movie night')
# (393, '2024-01-10', 26.25, 'Entertainment', 'Cash', 'Movie night')
# (394, '2024-01-17', 123.1, 'Transport', 'Dedit card', 'News hotel consumer provide.')
# (395, '2023-12-11', 191.5, 'Utilities', 'Bank transfer', 'Electricity bill')
# (396, '2023-12-16', 27.94, 'Entertainment', 'Cash', 'Low agreement understand identify.')
# (397, '2023-12-15', 38.78, 'Entertainment', 'Cash', 'Perform drug dog himself figure.')
# (398, '2024-01-12', 47.3, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (399, '2024-02-01', 69.12, 'Health care', 'Credit card', 'Pharmacy visit')
# (400, '2024-01-03', 36.84, 'Entertainment', 'Cash', 'Occur word clear.')
# (401, '2024-01-11', 26.99, 'Entertainment', 'Cash', 'Movie night')
# (402, '2024-02-02', 77.12, 'Health care', 'Credit card', 'Pharmacy visit')
# (403, '2023-12-12', 37.83, 'Entertainment', 'Cash', 'Lot her everyone.')
# (404, '2023-12-03', 42.36, 'Groceries', 'Credit card', 'Policy mean gas.')
# (405, '2024-01-04', 66.03, 'Health care', 'Credit card', 'Pharmacy visit')
# (406, '2024-01-16', 66.96, 'Health care', 'Credit card', 'Pharmacy visit')
# (407, '2023-12-15', 206.12, 'Utilities', 'Bank transfer', 'Pay responsibility capital hard course month.')
# (408, '2023-12-28', 35.48, 'Entertainment', 'Cash', 'Movie night')
# (409, '2023-12-16', 191.98, 'Utilities', 'Bank transfer', 'Electricity bill')
# (410, '2023-12-11', 75.8, 'Health care', 'Credit card', 'Political break any.')
# (411, '2024-01-04', 198.17, 'Utilities', 'Bank transfer', 'Electricity bill')
# (412, '2023-12-20', 112.56, 'Transport', 'Dedit card', 'Environmental I alone gas build.')
# (413, '2023-12-08', 32.01, 'Entertainment', 'Cash', 'Available next campaign natural.')
# (414, '2024-01-28', 42.69, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (415, '2024-01-30', 193.55, 'Utilities', 'Bank transfer', 'Electricity bill')
# (416, '2023-12-06', 26.32, 'Entertainment', 'Cash', 'Movie night')
# (417, '2023-12-18', 58.55, 'Groceries', 'Credit card', 'Approach buy behavior consumer reveal.')
# (418, '2023-12-20', 119.36, 'Transport', 'Dedit card', 'Together road view rather east rock.')
# (419, '2023-12-25', 35.8, 'Entertainment', 'Cash', 'Go travel recently floor.')
# (420, '2023-12-18', 57.49, 'Groceries', 'Credit card', 'Mind more government fish.')
# (421, '2024-01-07', 49.57, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (422, '2024-01-15', 205.19, 'Utilities', 'Bank transfer', 'Pay feeling professor.')
# (423, '2024-01-31', 34.55, 'Entertainment', 'Cash', 'Back identify peace.')
# (424, '2023-12-17', 29.68, 'Entertainment', 'Cash', 'Movie night')
# (425, '2024-01-11', 66.89, 'Health care', 'Credit card', 'Serve prepare culture future morning.')
# (426, '2024-01-05', 76.59, 'Health care', 'Credit card', 'Pharmacy visit')
# (427, '2024-01-07', 199.47, 'Utilities', 'Bank transfer', 'Claim action former.')
# (428, '2024-01-03', 25.79, 'Entertainment', 'Cash', 'Charge school bank.')
# (429, '2024-01-23', 72.5, 'Health care', 'Credit card', 'Pharmacy visit')
# (430, '2024-02-01', 66.76, 'Health care', 'Credit card', 'Pharmacy visit')
# (431, '2024-02-02', 30.32, 'Entertainment', 'Cash', 'Democrat pay own sense control.')
# (432, '2023-12-15', 200.17, 'Utilities', 'Bank transfer', 'Electricity bill')
# (433, '2023-12-28', 26.43, 'Entertainment', 'Cash', 'Movie night')
# (434, '2024-01-23', 30.73, 'Entertainment', 'Cash', 'Movie night')
# (435, '2023-12-29', 119.87, 'Transport', 'Dedit card', 'Monthly bus pass')
# (436, '2024-01-22', 26.74, 'Entertainment', 'Cash', 'Purpose full against control down.')
# (437, '2023-12-19', 72.1, 'Health care', 'Credit card', 'Pharmacy visit')
# (438, '2023-12-23', 75.84, 'Health care', 'Credit card', 'Pharmacy visit')
# (439, '2024-01-04', 33.25, 'Entertainment', 'Cash', 'Movie night')
# (440, '2023-12-26', 82.13, 'Health care', 'Credit card', 'East employee herself information leader full.')
# (441, '2024-01-28', 121.64, 'Transport', 'Dedit card', 'Safe onto run skin fear Democrat.')
# (442, '2024-01-20', 201.85, 'Utilities', 'Bank transfer', 'Electricity bill')
# (443, '2024-01-05', 56.88, 'Groceries', 'Credit card', 'Foot what next.')
# (444, '2023-12-18', 78.87, 'Health care', 'Credit card', 'Whether add certainly agency law.')
# (445, '2023-12-07', 43.11, 'Groceries', 'Credit card', 'Wait say movie.')
# (446, '2023-12-22', 43.59, 'Groceries', 'Credit card', 'Prove board economy.')
# (447, '2024-01-27', 44.4, 'Groceries', 'Credit card', 'Scene story mission spend.')
# (448, '2024-01-03', 54.74, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (449, '2024-01-10', 197.09, 'Utilities', 'Bank transfer', 'Electricity bill')
# (450, '2024-01-28', 198.83, 'Utilities', 'Bank transfer', 'Electricity bill')
# (451, '2024-01-02', 198.81, 'Utilities', 'Bank transfer', 'Light treatment fact skin.')
# (452, '2024-01-31', 35.45, 'Entertainment', 'Cash', 'Read force forget media present because price.')
# (453, '2023-12-28', 42.27, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (454, '2024-01-17', 44.89, 'Groceries', 'Credit card', 'Word like our.')
# (455, '2024-02-03', 75.27, 'Health care', 'Credit card', 'Rate large daughter right.')
# (456, '2024-01-29', 50.57, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (457, '2024-01-08', 112.03, 'Transport', 'Dedit card', 'Chance dinner in.')
# (458, '2024-01-08', 75.3, 'Health care', 'Credit card', 'Share with kitchen artist evening same.')
# (459, '2024-01-27', 28.2, 'Entertainment', 'Cash', 'View authority thought media none.')
# (460, '2023-12-29', 69.98, 'Health care', 'Credit card', 'Democrat partner nice try.')
# (461, '2023-12-16', 42.98, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (462, '2023-12-29', 33.79, 'Entertainment', 'Cash', 'Experience ground share environmental carry similar.')
# (463, '2023-12-15', 119.8, 'Transport', 'Dedit card', 'Monthly bus pass')
# (464, '2023-12-02', 55.88, 'Groceries', 'Credit card', 'None respond off here two.')
# (465, '2024-01-17', 24.61, 'Entertainment', 'Cash', 'Design available doctor deal.')
# (466, '2023-12-31', 58.45, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (467, '2024-01-26', 47.05, 'Groceries', 'Credit card', 'Trouble billion would than well early.')
# (468, '2023-12-08', 125.06, 'Transport', 'Dedit card', 'Notice apply treat least hard together standard.')
# (469, '2024-01-23', 43.04, 'Groceries', 'Credit card', 'Rate same born.')
# (470, '2023-12-13', 194.42, 'Utilities', 'Bank transfer', 'Not water sense card he.')
# (471, '2023-12-10', 119.07, 'Transport', 'Dedit card', 'Before often teacher deep blue case.')
# (472, '2024-01-15', 65.55, 'Health care', 'Credit card', 'Pharmacy visit')
# (473, '2024-01-09', 194.27, 'Utilities', 'Bank transfer', 'Electricity bill')
# (474, '2023-12-29', 45.33, 'Groceries', 'Credit card', 'Either smile whose.')
# (475, '2023-12-29', 128.68, 'Transport', 'Dedit card', 'Situation body born condition.')
# (476, '2024-01-22', 48.42, 'Groceries', 'Credit card', 'Green somebody market.')
# (477, '2023-12-15', 77.36, 'Health care', 'Credit card', 'Far condition thus since so.')
# (478, '2023-12-31', 78.71, 'Health care', 'Credit card', 'Pharmacy visit')
# (479, '2023-12-05', 120.85, 'Transport', 'Dedit card', 'Tell air myself.')
# (480, '2024-01-04', 79.74, 'Health care', 'Credit card', 'Account pull it.')
# (481, '2023-12-27', 72.92, 'Health care', 'Credit card', 'Several free operation beyond.')
# (482, '2024-01-14', 45.91, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (483, '2023-12-18', 118.75, 'Transport', 'Dedit card', 'Ahead others unit situation.')
# (484, '2024-01-13', 115.71, 'Transport', 'Dedit card', 'Whose final would race indicate choose.')
# (485, '2024-01-03', 196.35, 'Utilities', 'Bank transfer', 'Number girl his television.')
# (486, '2024-01-01', 127.89, 'Transport', 'Dedit card', 'Monthly bus pass')
# (487, '2023-12-04', 126.8, 'Transport', 'Dedit card', 'Monthly bus pass')
# (488, '2023-12-06', 73.69, 'Health care', 'Credit card', 'Black anyone itself.')
# (489, '2023-12-16', 206.58, 'Utilities', 'Bank transfer', 'President personal fall one development save.')
# (490, '2023-12-18', 34.6, 'Entertainment', 'Cash', 'Agree break or sport upon our.')
# (491, '2023-12-27', 127.01, 'Transport', 'Dedit card', 'Back itself cover even treatment per.')
# (492, '2023-12-10', 44.62, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (493, '2024-02-03', 192.77, 'Utilities', 'Bank transfer', 'Wide position student happen color care.')
# (494, '2023-12-20', 48.14, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (495, '2024-01-13', 42.07, 'Groceries', 'Credit card', 'Cultural fine teach bring best both.')
# (496, '2024-01-07', 83.8, 'Health care', 'Credit card', 'Pharmacy visit')
# (497, '2023-12-16', 191.47, 'Utilities', 'Bank transfer', 'Here nice before likely.')
# (498, '2024-01-29', 112.95, 'Transport', 'Dedit card', 'Monthly bus pass')
# (499, '2024-01-28', 117.14, 'Transport', 'Dedit card', 'Monthly bus pass')
# (500, '2023-12-08', 128.35, 'Transport', 'Dedit card', 'Monthly bus pass')
# (501, '2023-12-22', 24.91, 'Entertainment', 'Cash', 'Movie night')
# (502, '2024-01-16', 24.53, 'Entertainment', 'Cash', 'Movie night')
# (503, '2023-12-08', 198.37, 'Utilities', 'Bank transfer', 'Electricity bill')
# (504, '2024-01-13', 209.81, 'Utilities', 'Bank transfer', 'Electricity bill')
# (505, '2024-01-23', 129.55, 'Transport', 'Dedit card', 'Monthly bus pass')
# (506, '2023-12-20', 194.42, 'Utilities', 'Bank transfer', 'Electricity bill')
# (507, '2024-01-09', 125.7, 'Transport', 'Dedit card', 'Monthly bus pass')
# (508, '2023-12-29', 206.45, 'Utilities', 'Bank transfer', 'Keep car better gun among.')
# (509, '2024-02-02', 23.02, 'Entertainment', 'Cash', 'Movie night')
# (510, '2024-01-22', 25.32, 'Entertainment', 'Cash', 'Movie night')
# (511, '2024-01-09', 67.92, 'Health care', 'Credit card', 'Plant medical off then.')
# (512, '2023-12-20', 40.79, 'Groceries', 'Credit card', 'Democratic for from pick.')
# (513, '2024-01-05', 127.7, 'Transport', 'Dedit card', 'Monthly bus pass')
# (514, '2023-12-31', 23.7, 'Entertainment', 'Cash', 'Increase see test important.')
# (515, '2024-01-15', 126.75, 'Transport', 'Dedit card', 'Monthly bus pass')
# (516, '2024-01-18', 51.9, 'Groceries', 'Credit card', 'Give job city group you response.')
# (517, '2023-12-10', 24.09, 'Entertainment', 'Cash', 'Miss reveal audience seat energy may.')
# (518, '2024-01-21', 208.29, 'Utilities', 'Bank transfer', 'Very father bar approach instead.')
# (519, '2024-01-26', 193.83, 'Utilities', 'Bank transfer', 'Win above next sing fight like.')
# (520, '2024-01-14', 55.84, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (521, '2024-01-08', 77.87, 'Health care', 'Credit card', 'Pharmacy visit')
# (522, '2024-01-08', 120.45, 'Transport', 'Dedit card', 'Hear room education later help him.')
# (523, '2024-01-11', 34.52, 'Entertainment', 'Cash', 'Bad arm moment through seven dream.')
# (524, '2024-01-04', 115.38, 'Transport', 'Dedit card', 'Finish once fact white.')
# (525, '2024-01-03', 191.29, 'Utilities', 'Bank transfer', 'Electricity bill')
# (526, '2023-12-25', 196.25, 'Utilities', 'Bank transfer', 'Wear possible bill ten.')
# (527, '2024-01-16', 56.62, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (528, '2023-12-22', 26.81, 'Entertainment', 'Cash', 'Shoulder mind point single.')
# (529, '2023-12-23', 74.33, 'Health care', 'Credit card', 'Cost toward black check.')
# (530, '2024-01-10', 30.88, 'Entertainment', 'Cash', 'Movie night')
# (531, '2024-01-20', 38.06, 'Entertainment', 'Cash', 'Movie night')
# (532, '2023-12-22', 193.37, 'Utilities', 'Bank transfer', 'Electricity bill')
# (533, '2023-12-22', 30.49, 'Entertainment', 'Cash', 'Movie night')
# (534, '2024-01-07', 52.42, 'Groceries', 'Credit card', 'Sign ok money.')
# (535, '2024-01-01', 35.47, 'Entertainment', 'Cash', 'So quality girl decision.')
# (536, '2023-12-07', 22.3, 'Entertainment', 'Cash', 'Walk money day role argue.')
# (537, '2024-01-25', 191.53, 'Utilities', 'Bank transfer', 'Against stop student.')
# (538, '2024-01-24', 114.0, 'Transport', 'Dedit card', 'Monthly bus pass')
# (539, '2024-01-09', 208.73, 'Utilities', 'Bank transfer', 'Detail however born spend oil.')
# (540, '2023-12-18', 199.52, 'Utilities', 'Bank transfer', 'Different owner despite him speech.')
# (541, '2024-01-13', 203.84, 'Utilities', 'Bank transfer', 'Develop rate analysis thing idea.')
# (542, '2024-01-25', 75.68, 'Health care', 'Credit card', 'Pharmacy visit')
# (543, '2023-12-16', 81.69, 'Health care', 'Credit card', 'Pharmacy visit')
# (544, '2023-12-07', 110.9, 'Transport', 'Dedit card', 'Available room serious.')
# (545, '2023-12-18', 55.53, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (546, '2023-12-22', 82.46, 'Health care', 'Credit card', 'I eat million own line various.')
# (547, '2024-01-27', 20.62, 'Entertainment', 'Cash', 'Movie night')
# (548, '2023-12-15', 128.98, 'Transport', 'Dedit card', 'Capital draw technology account unit.')
# (549, '2023-12-24', 114.28, 'Transport', 'Dedit card', 'Show day let interest language.')
# (550, '2023-12-10', 206.21, 'Utilities', 'Bank transfer', 'Mr left represent may give father.')
# (551, '2024-01-24', 111.99, 'Transport', 'Dedit card', 'Eye son conference.')
# (552, '2023-12-05', 50.96, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (553, '2024-01-01', 50.23, 'Groceries', 'Credit card', 'Possible recent range position value.')
# (554, '2023-12-06', 81.19, 'Health care', 'Credit card', 'Tax question business.')
# (555, '2024-01-02', 36.42, 'Entertainment', 'Cash', 'Movie night')
# (556, '2024-01-31', 197.15, 'Utilities', 'Bank transfer', 'Out different indicate feel phone watch.')
# (557, '2024-01-29', 38.3, 'Entertainment', 'Cash', 'Movie night')
# (558, '2023-12-16', 118.86, 'Transport', 'Dedit card', 'See skill major protect.')
# (559, '2023-12-10', 70.51, 'Health care', 'Credit card', 'Pharmacy visit')
# (560, '2024-01-22', 35.69, 'Entertainment', 'Cash', 'Movie night')
# (561, '2023-12-15', 21.65, 'Entertainment', 'Cash', 'Discussion often less themselves partner.')
# (562, '2023-12-18', 122.69, 'Transport', 'Dedit card', 'List guy support accept draw another.')
# (563, '2023-12-11', 80.32, 'Health care', 'Credit card', 'Pharmacy visit')
# (564, '2024-01-31', 110.86, 'Transport', 'Dedit card', 'Chair home listen offer.')
# (565, '2024-01-22', 192.94, 'Utilities', 'Bank transfer', 'Electricity bill')
# (566, '2023-12-15', 79.36, 'Health care', 'Credit card', 'Gas other anything whether.')
# (567, '2023-12-25', 32.62, 'Entertainment', 'Cash', 'Certain born yourself great hold.')
# (568, '2024-01-22', 49.75, 'Groceries', 'Credit card', 'Little me they letter third great.')
# (569, '2024-01-28', 205.49, 'Utilities', 'Bank transfer', 'Late imagine someone production political.')
# (570, '2024-01-06', 124.08, 'Transport', 'Dedit card', 'Monthly bus pass')
# (571, '2024-01-15', 197.33, 'Utilities', 'Bank transfer', 'Meeting nearly these.')
# (572, '2023-12-12', 25.09, 'Entertainment', 'Cash', 'Loss network write simply purpose.')
# (573, '2023-12-09', 71.4, 'Health care', 'Credit card', 'Process popular fear.')
# (574, '2023-12-21', 199.53, 'Utilities', 'Bank transfer', 'Bring area usually.')
# (575, '2024-01-12', 200.41, 'Utilities', 'Bank transfer', 'Electricity bill')
# (576, '2023-12-23', 22.92, 'Entertainment', 'Cash', 'Movie night')
# (577, '2023-12-23', 111.61, 'Transport', 'Dedit card', 'May ahead cup visit space.')
# (578, '2024-02-01', 34.41, 'Entertainment', 'Cash', 'Expect court staff different.')
# (579, '2023-12-07', 51.96, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (580, '2024-01-12', 198.9, 'Utilities', 'Bank transfer', 'Pass cup get company.')
# (581, '2024-01-10', 81.46, 'Health care', 'Credit card', 'Pharmacy visit')
# (582, '2023-12-24', 26.03, 'Entertainment', 'Cash', 'Movie night')
# (583, '2024-01-07', 209.95, 'Utilities', 'Bank transfer', 'Electricity bill')
# (584, '2024-01-10', 40.66, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (585, '2023-12-13', 209.37, 'Utilities', 'Bank transfer', 'Tend learn popular business model.')
# (586, '2023-12-19', 71.6, 'Health care', 'Credit card', 'Pharmacy visit')
# (587, '2023-12-19', 110.09, 'Transport', 'Dedit card', 'While establish successful kid.')
# (588, '2023-12-24', 42.44, 'Groceries', 'Credit card', 'Life these case.')
# (589, '2023-12-11', 41.34, 'Groceries', 'Credit card', 'Yard board fund term board surface.')
# (590, '2024-01-07', 72.47, 'Health care', 'Credit card', 'Pharmacy visit')
# (591, '2024-01-23', 124.45, 'Transport', 'Dedit card', 'Monthly bus pass')
# (592, '2023-12-23', 79.52, 'Health care', 'Credit card', 'Country capital rest these southern.')
# ...
# (810, '2023-12-06', 78.17, 'Health care', 'Credit card', 'Change during price.')
# (811, '2023-12-14', 111.64, 'Transport', 'Dedit card', 'Soldier cause view of director exactly.')
# (812, '2024-01-05', 37.77, 'Entertainment', 'Cash', 'Tell issue site.')
# (813, '2023-12-26', 66.22, 'Health care', 'Credit card', 'Nearly reveal third perhaps.')
# (814, '2024-01-27', 122.06, 'Transport', 'Dedit card', 'Monthly bus pass')
# (815, '2023-12-14', 36.91, 'Entertainment', 'Cash', 'Already wide voice.')
# (816, '2024-01-17', 74.02, 'Health care', 'Credit card', 'Car let fast.')
# (817, '2024-01-18', 81.97, 'Health care', 'Credit card', 'Guess note ball simply.')
# (818, '2024-01-19', 44.84, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (819, '2023-12-11', 76.51, 'Health care', 'Credit card', 'Also majority design first father.')
# (820, '2023-12-24', 122.98, 'Transport', 'Dedit card', 'Monthly bus pass')
# (821, '2024-01-10', 198.04, 'Utilities', 'Bank transfer', 'Electricity bill')
# (822, '2023-12-16', 115.79, 'Transport', 'Dedit card', 'Think figure party really stay glass big.')
# (823, '2023-12-15', 110.14, 'Transport', 'Dedit card', 'Education sense sister learn any lot.')
# (824, '2023-12-29', 44.59, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (825, '2024-01-30', 39.61, 'Entertainment', 'Cash', 'Information simple defense seem tough heavy.')
# (826, '2024-01-11', 32.92, 'Entertainment', 'Cash', 'Movie night')
# (827, '2024-01-28', 111.83, 'Transport', 'Dedit card', 'Stand individual factor stop focus listen.')
# (828, '2023-12-20', 206.91, 'Utilities', 'Bank transfer', 'Weight now culture itself result grow.')
# (829, '2024-01-13', 67.05, 'Health care', 'Credit card', 'Pharmacy visit')
# (830, '2023-12-15', 73.97, 'Health care', 'Credit card', 'Establish center alone it.')
# (831, '2024-01-28', 205.93, 'Utilities', 'Bank transfer', 'Mention nation grow movement country government.')
# (832, '2023-12-17', 123.68, 'Transport', 'Dedit card', 'Little point almost around.')
# (833, '2024-01-24', 126.14, 'Transport', 'Dedit card', 'Monthly bus pass')
# (834, '2024-01-14', 21.81, 'Entertainment', 'Cash', 'Seek dream hold smile every pressure.')
# (835, '2024-01-10', 192.31, 'Utilities', 'Bank transfer', 'Hold institution matter large natural father.')
# (836, '2024-01-17', 44.46, 'Groceries', 'Credit card', 'Toward radio send.')
# (837, '2024-01-05', 40.96, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (838, '2024-01-11', 58.45, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (839, '2023-12-19', 197.66, 'Utilities', 'Bank transfer', 'Electricity bill')
# (840, '2023-12-11', 83.42, 'Health care', 'Credit card', 'Pharmacy visit')
# (841, '2023-12-27', 111.72, 'Transport', 'Dedit card', 'Monthly bus pass')
# (842, '2023-12-06', 53.78, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (843, '2024-01-14', 68.66, 'Health care', 'Credit card', 'Film democratic your.')
# (844, '2024-01-25', 122.81, 'Transport', 'Dedit card', 'Might deal technology bring.')
# (845, '2024-01-02', 29.59, 'Entertainment', 'Cash', 'Ten bed I technology group rest.')
# (846, '2024-01-12', 76.51, 'Health care', 'Credit card', 'Police analysis yet.')
# (847, '2024-01-23', 51.94, 'Groceries', 'Credit card', 'Soon ability concern.')
# (848, '2023-12-07', 43.98, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (849, '2024-01-10', 54.17, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (850, '2023-12-05', 43.48, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (851, '2023-12-10', 209.25, 'Utilities', 'Bank transfer', 'Electricity bill')
# (852, '2024-01-31', 51.02, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (853, '2024-01-27', 116.65, 'Transport', 'Dedit card', 'Former involve tax through including.')
# (854, '2023-12-05', 128.66, 'Transport', 'Dedit card', 'Monthly bus pass')
# (855, '2023-12-08', 205.77, 'Utilities', 'Bank transfer', 'Electricity bill')
# (856, '2023-12-25', 44.63, 'Groceries', 'Credit card', 'Mind way decide Mr.')
# (857, '2023-12-18', 44.03, 'Groceries', 'Credit card', 'After direction really.')
# (858, '2024-01-19', 39.18, 'Entertainment', 'Cash', 'Movie night')
# (859, '2024-01-28', 31.32, 'Entertainment', 'Cash', 'Baby maintain especially.')
# (860, '2024-01-12', 80.04, 'Health care', 'Credit card', 'Seven social wide clear concern skill.')
# (861, '2023-12-24', 204.38, 'Utilities', 'Bank transfer', 'Interest ago job ready prove improve.')
# (862, '2024-01-25', 25.81, 'Entertainment', 'Cash', 'Movie night')
# (863, '2023-12-16', 198.09, 'Utilities', 'Bank transfer', 'Electricity bill')
# (864, '2023-12-09', 36.88, 'Entertainment', 'Cash', 'Movie night')
# (865, '2024-01-08', 203.72, 'Utilities', 'Bank transfer', 'Receive short which seek condition.')
# (866, '2023-12-23', 205.71, 'Utilities', 'Bank transfer', 'Electricity bill')
# (867, '2024-01-20', 209.0, 'Utilities', 'Bank transfer', 'Electricity bill')
# (868, '2024-01-16', 83.89, 'Health care', 'Credit card', 'No entire return country but.')
# (869, '2023-12-21', 48.44, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (870, '2023-12-15', 34.77, 'Entertainment', 'Cash', 'Per pretty produce room nothing maintain.')
# (871, '2024-01-03', 68.06, 'Health care', 'Credit card', 'Plan often official wall alone.')
# (872, '2023-12-31', 207.7, 'Utilities', 'Bank transfer', 'Benefit serious without miss.')
# (873, '2023-12-13', 197.2, 'Utilities', 'Bank transfer', 'Sea perform range perform official form.')
# (874, '2023-12-18', 22.45, 'Entertainment', 'Cash', 'Movie night')
# (875, '2024-02-01', 197.86, 'Utilities', 'Bank transfer', 'Electricity bill')
# (876, '2024-01-25', 76.18, 'Health care', 'Credit card', 'Century admit reality because become.')
# (877, '2024-01-21', 22.66, 'Entertainment', 'Cash', 'Piece collection agency until movie project.')
# (878, '2024-01-04', 40.27, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (879, '2024-01-30', 122.54, 'Transport', 'Dedit card', 'Benefit since mouth return individual knowledge.')
# (880, '2023-12-12', 67.55, 'Health care', 'Credit card', 'Pharmacy visit')
# (881, '2023-12-23', 72.56, 'Health care', 'Credit card', 'Pharmacy visit')
# (882, '2024-01-05', 27.92, 'Entertainment', 'Cash', 'Team write use anything.')
# (883, '2024-01-08', 111.26, 'Transport', 'Dedit card', 'Monthly bus pass')
# (884, '2024-01-18', 24.51, 'Entertainment', 'Cash', 'Cut ago thought.')
# (885, '2024-01-05', 45.83, 'Groceries', 'Credit card', 'Treat responsibility beat.')
# (886, '2024-01-16', 121.7, 'Transport', 'Dedit card', 'Monthly bus pass')
# (887, '2023-12-22', 48.13, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (888, '2024-01-24', 121.8, 'Transport', 'Dedit card', 'Monthly bus pass')
# (889, '2023-12-11', 206.37, 'Utilities', 'Bank transfer', 'Live above music and somebody situation.')
# (890, '2023-12-26', 74.73, 'Health care', 'Credit card', 'Kid fund energy maybe especially.')
# (891, '2023-12-07', 65.1, 'Health care', 'Credit card', 'Against charge director add add.')
# (892, '2024-01-05', 54.87, 'Groceries', 'Credit card', 'I add guy large.')
# (893, '2023-12-19', 202.46, 'Utilities', 'Bank transfer', 'Argue understand chair.')
# (894, '2023-12-25', 45.87, 'Groceries', 'Credit card', 'Quickly her continue.')
# (895, '2023-12-14', 83.68, 'Health care', 'Credit card', 'Stock scientist Congress director.')
# (896, '2024-02-04', 73.18, 'Health care', 'Credit card', 'Develop expect require son toward phone.')
# (897, '2024-01-10', 56.67, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (898, '2024-01-18', 56.44, 'Groceries', 'Credit card', 'Moment simple wear.')
# (899, '2023-12-11', 121.9, 'Transport', 'Dedit card', 'Monthly bus pass')
# (900, '2024-01-03', 70.87, 'Health care', 'Credit card', 'Item range low opportunity start.')
# (901, '2024-01-30', 51.25, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (902, '2024-02-01', 197.25, 'Utilities', 'Bank transfer', 'Electricity bill')
# (903, '2023-12-21', 195.56, 'Utilities', 'Bank transfer', 'Leg certainly book.')
# (904, '2024-01-08', 191.37, 'Utilities', 'Bank transfer', 'Knowledge month want instead.')
# (905, '2024-01-10', 125.45, 'Transport', 'Dedit card', 'Five hard easy about appear edge.')
# (906, '2023-12-04', 128.07, 'Transport', 'Dedit card', 'Monthly bus pass')
# (907, '2024-01-09', 123.14, 'Transport', 'Dedit card', 'Monthly bus pass')
# (908, '2024-01-30', 191.9, 'Utilities', 'Bank transfer', 'Evening dog market people politics surface.')
# (909, '2023-12-31', 67.89, 'Health care', 'Credit card', 'Style sit fund key difficult surface anyone.')
# (910, '2023-12-31', 195.5, 'Utilities', 'Bank transfer', 'Network low kitchen return media surface.')
# (911, '2023-12-15', 40.28, 'Groceries', 'Credit card', 'Arrive remain bar address yeah event.')
# (912, '2024-01-24', 190.39, 'Utilities', 'Bank transfer', 'Especially address traditional may.')
# (913, '2023-12-19', 42.75, 'Groceries', 'Credit card', 'Operation international level.')
# (914, '2023-12-29', 68.08, 'Health care', 'Credit card', 'Pharmacy visit')
# (915, '2023-12-29', 32.97, 'Entertainment', 'Cash', 'Garden board type plan.')
# (916, '2023-12-13', 52.58, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (917, '2023-12-05', 42.85, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (918, '2023-12-25', 114.64, 'Transport', 'Dedit card', 'Monthly bus pass')
# (919, '2024-01-23', 66.35, 'Health care', 'Credit card', 'Pharmacy visit')
# (920, '2024-01-11', 44.32, 'Groceries', 'Credit card', 'Expert statement physical energy official series job.')
# (921, '2024-01-25', 73.5, 'Health care', 'Credit card', 'Pharmacy visit')
# (922, '2024-01-28', 35.0, 'Entertainment', 'Cash', 'Official collection inside world his.')
# (923, '2023-12-15', 194.57, 'Utilities', 'Bank transfer', 'He knowledge white camera.')
# (924, '2023-12-27', 196.55, 'Utilities', 'Bank transfer', 'Electricity bill')
# (925, '2023-12-29', 66.54, 'Health care', 'Credit card', 'When boy already live available.')
# (926, '2024-01-01', 119.22, 'Transport', 'Dedit card', 'Free the country discover such.')
# (927, '2024-01-21', 58.77, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (928, '2024-01-02', 202.97, 'Utilities', 'Bank transfer', 'Electricity bill')
# (929, '2023-12-12', 201.43, 'Utilities', 'Bank transfer', 'Electricity bill')
# (930, '2023-12-06', 81.3, 'Health care', 'Credit card', 'News south believe society.')
# (931, '2024-01-14', 192.3, 'Utilities', 'Bank transfer', 'Oil figure arrive.')
# (932, '2024-01-31', 191.82, 'Utilities', 'Bank transfer', 'Electricity bill')
# (933, '2024-01-26', 42.45, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (934, '2023-12-09', 80.9, 'Health care', 'Credit card', 'Imagine later stock occur challenge.')
# (935, '2023-12-09', 120.89, 'Transport', 'Dedit card', 'Monthly bus pass')
# (936, '2023-12-17', 51.4, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (937, '2024-01-07', 205.09, 'Utilities', 'Bank transfer', 'Electricity bill')
# (938, '2024-01-02', 127.15, 'Transport', 'Dedit card', 'Monthly bus pass')
# (939, '2023-12-10', 201.76, 'Utilities', 'Bank transfer', 'Electricity bill')
# (940, '2024-01-10', 126.77, 'Transport', 'Dedit card', 'Monthly bus pass')
# (941, '2024-01-06', 126.17, 'Transport', 'Dedit card', 'Monthly bus pass')
# (942, '2024-01-27', 27.19, 'Entertainment', 'Cash', 'Civil development book interesting set movement.')
# (943, '2023-12-29', 54.99, 'Groceries', 'Credit card', 'Employee recognize see.')
# (944, '2024-01-27', 125.58, 'Transport', 'Dedit card', 'Monthly bus pass')
# (945, '2023-12-08', 67.73, 'Health care', 'Credit card', 'Exist strong five enjoy future under.')
# (946, '2023-12-27', 39.1, 'Entertainment', 'Cash', 'Movie night')
# (947, '2023-12-30', 126.84, 'Transport', 'Dedit card', 'Something serve store brother fill hot.')
# (948, '2023-12-21', 32.85, 'Entertainment', 'Cash', 'Movie night')
# (949, '2024-01-14', 67.26, 'Health care', 'Credit card', 'Pharmacy visit')
# (950, '2024-01-16', 48.89, 'Groceries', 'Credit card', 'Sister respond PM economy democratic detail.')
# (951, '2023-12-23', 122.13, 'Transport', 'Dedit card', 'Direction budget bed visit not.')
# (952, '2024-01-25', 42.17, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (953, '2024-01-30', 66.23, 'Health care', 'Credit card', 'Word serious director.')
# (954, '2024-01-12', 115.94, 'Transport', 'Dedit card', 'Monthly bus pass')
# (955, '2023-12-31', 68.7, 'Health care', 'Credit card', 'Head inside almost source always.')
# (956, '2023-12-29', 36.89, 'Entertainment', 'Cash', 'Away call prove.')
# (957, '2023-12-14', 21.18, 'Entertainment', 'Cash', 'Movie night')
# (958, '2024-01-24', 111.81, 'Transport', 'Dedit card', 'Monthly bus pass')
# (959, '2024-01-27', 71.55, 'Health care', 'Credit card', 'Head leave concern kind response specific.')
# (960, '2023-12-17', 34.33, 'Entertainment', 'Cash', 'Movie night')
# (961, '2024-01-02', 20.96, 'Entertainment', 'Cash', 'Positive measure several group.')
# (962, '2024-01-29', 76.32, 'Health care', 'Credit card', 'Pharmacy visit')
# (963, '2024-01-11', 201.99, 'Utilities', 'Bank transfer', 'Electricity bill')
# (964, '2023-12-29', 42.71, 'Groceries', 'Credit card', 'Theory ask just admit religious little.')
# (965, '2023-12-19', 190.3, 'Utilities', 'Bank transfer', 'Health for condition maintain.')
# (966, '2024-01-21', 50.35, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (967, '2023-12-06', 44.11, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (968, '2024-01-26', 46.76, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (969, '2023-12-11', 111.68, 'Transport', 'Dedit card', 'Thing usually listen meet.')
# (970, '2023-12-25', 31.35, 'Entertainment', 'Cash', 'Movie night')
# (971, '2024-01-07', 77.55, 'Health care', 'Credit card', 'Pharmacy visit')
# (972, '2023-12-10', 32.33, 'Entertainment', 'Cash', 'Artist learn clearly develop war some.')
# (973, '2023-12-18', 84.66, 'Health care', 'Credit card', 'Pharmacy visit')
# (974, '2024-02-01', 115.35, 'Transport', 'Dedit card', 'Monthly bus pass')
# (975, '2023-12-17', 65.51, 'Health care', 'Credit card', 'Pharmacy visit')
# (976, '2024-02-02', 25.84, 'Entertainment', 'Cash', 'Movie night')
# (977, '2024-01-08', 124.32, 'Transport', 'Dedit card', 'Monthly bus pass')
# (978, '2024-01-15', 40.29, 'Groceries', 'Credit card', 'Away car ever know case.')
# (979, '2024-01-28', 48.05, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (980, '2023-12-14', 123.24, 'Transport', 'Dedit card', 'Former include agency quality law cell.')
# (981, '2023-12-06', 45.85, 'Groceries', 'Credit card', 'Oil new purpose every say.')
# (982, '2023-12-30', 21.98, 'Entertainment', 'Cash', 'Movie night')
# (983, '2023-12-21', 115.15, 'Transport', 'Dedit card', 'Media door number represent paper participant protect.')
# (984, '2024-01-17', 81.97, 'Health care', 'Credit card', 'Pharmacy visit')
# (985, '2024-01-12', 33.69, 'Entertainment', 'Cash', 'Movie night')
# (986, '2024-01-16', 118.68, 'Transport', 'Dedit card', 'Monthly bus pass')
# (987, '2024-01-07', 129.88, 'Transport', 'Dedit card', 'Monthly bus pass')
# (988, '2024-02-04', 68.25, 'Health care', 'Credit card', 'Write black scientist.')
# (989, '2023-12-20', 53.88, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (990, '2023-12-10', 72.28, 'Health care', 'Credit card', 'Pharmacy visit')
# (991, '2023-12-26', 31.38, 'Entertainment', 'Cash', 'Movie night')
# (992, '2024-02-03', 201.57, 'Utilities', 'Bank transfer', 'Pattern trade practice control life go toward.')
# (993, '2023-12-02', 52.07, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (994, '2023-12-27', 50.12, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (995, '2023-12-11', 41.88, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (996, '2023-12-08', 80.27, 'Health care', 'Credit card', 'Western save buy reach.')
# (997, '2023-12-03', 119.0, 'Transport', 'Dedit card', 'Rate next open.')
# (998, '2023-12-27', 199.05, 'Utilities', 'Bank transfer', 'News camera young threat.')
# (999, '2024-02-03', 198.38, 'Utilities', 'Bank transfer', 'Electricity bill')
# (1000, '2024-01-17', 75.82, 'Health care', 'Credit card', 'Account car feel whose you ready.')

# %% [markdown]
# ### 2. Filter by Category

# %%
category='Groceries'
cursor.execute("SELECT * FROM expense WHERE category=?",(category,))
rows=cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (7, '2024-01-01', 57.46, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (11, '2024-01-24', 54.84, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (14, '2024-01-10', 55.95, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (19, '2023-12-08', 41.59, 'Groceries', 'Credit card', 'Happen boy write top leader hour.')
# (23, '2023-12-19', 43.59, 'Groceries', 'Credit card', 'Organization shoulder carry.')
# (25, '2023-12-08', 56.36, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (27, '2023-12-15', 56.13, 'Groceries', 'Credit card', 'On avoid authority.')
# (28, '2023-12-17', 46.66, 'Groceries', 'Credit card', 'Do stuff color become.')
# (32, '2023-12-04', 40.4, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (37, '2023-12-13', 49.4, 'Groceries', 'Credit card', 'While number start score.')
# (44, '2024-01-25', 52.97, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (55, '2023-12-30', 47.96, 'Groceries', 'Credit card', 'Wrong wish beyond.')
# (56, '2023-12-11', 55.9, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (57, '2023-12-11', 55.03, 'Groceries', 'Credit card', 'Race collection yet air.')
# (65, '2023-12-15', 43.31, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (69, '2023-12-20', 54.57, 'Groceries', 'Credit card', 'Lot design produce week either.')
# (70, '2023-12-12', 42.67, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (71, '2024-01-14', 59.98, 'Groceries', 'Credit card', 'Her board radio up.')
# (74, '2023-12-20', 57.09, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (76, '2024-01-26', 53.29, 'Groceries', 'Credit card', 'High occur follow.')
# (77, '2023-12-04', 51.72, 'Groceries', 'Credit card', 'Film white develop painting.')
# (81, '2023-12-26', 57.39, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (85, '2024-01-05', 50.47, 'Groceries', 'Credit card', 'Church public couple example information whose.')
# (86, '2023-12-09', 47.97, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (99, '2023-12-07', 59.76, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (102, '2023-12-24', 50.53, 'Groceries', 'Credit card', 'However base worry week.')
# (110, '2024-01-11', 44.23, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (124, '2024-01-10', 45.5, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (131, '2023-12-17', 44.47, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (139, '2023-12-04', 54.86, 'Groceries', 'Credit card', 'Mention party may day star.')
# (142, '2024-01-19', 59.98, 'Groceries', 'Credit card', 'Important would lose figure road.')
# (143, '2023-12-09', 55.91, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (145, '2024-01-17', 49.14, 'Groceries', 'Credit card', 'Area soon before million.')
# (149, '2024-01-11', 49.46, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (151, '2024-01-18', 41.89, 'Groceries', 'Credit card', 'Cultural its although hope issue.')
# (158, '2024-01-12', 41.12, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (160, '2024-01-26', 54.25, 'Groceries', 'Credit card', 'City agreement these job.')
# (162, '2023-12-05', 59.34, 'Groceries', 'Credit card', 'Method deal director.')
# (166, '2023-12-29', 55.2, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (179, '2024-01-24', 45.54, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (180, '2023-12-09', 55.08, 'Groceries', 'Credit card', 'Show word vote role wall.')
# (184, '2023-12-20', 58.23, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (186, '2024-01-24', 46.81, 'Groceries', 'Credit card', 'Us thank quickly realize after.')
# (202, '2024-01-16', 54.69, 'Groceries', 'Credit card', 'Some newspaper consumer organization really.')
# (212, '2024-01-27', 43.89, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (221, '2024-01-08', 49.41, 'Groceries', 'Credit card', 'Order store anyone performance.')
# (225, '2024-01-20', 48.1, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (230, '2024-01-25', 48.33, 'Groceries', 'Credit card', 'No task believe performance inside.')
# (231, '2023-12-15', 54.81, 'Groceries', 'Credit card', 'Guess run anything dark.')
# (233, '2023-12-12', 42.6, 'Groceries', 'Credit card', 'Both too agree.')
# (235, '2023-12-31', 47.61, 'Groceries', 'Credit card', 'Standard author begin voice.')
# (238, '2024-01-29', 41.05, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (244, '2023-12-19', 49.64, 'Groceries', 'Credit card', 'Feeling dream too public child concern.')
# (245, '2023-12-09', 44.46, 'Groceries', 'Credit card', 'Oil then read miss.')
# (247, '2023-12-21', 57.98, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (256, '2024-01-18', 59.46, 'Groceries', 'Credit card', 'Too religious customer physical rest.')
# (260, '2023-12-16', 50.09, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (269, '2023-12-29', 53.11, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (271, '2023-12-25', 41.41, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (273, '2024-01-17', 41.4, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (274, '2023-12-11', 40.06, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (275, '2023-12-24', 41.86, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (276, '2024-01-17', 59.54, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (281, '2024-01-03', 43.03, 'Groceries', 'Credit card', 'Method occur concern drive.')
# (290, '2024-01-01', 49.85, 'Groceries', 'Credit card', 'Some president note result consider.')
# (296, '2023-12-16', 46.27, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (305, '2024-01-30', 51.42, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (313, '2024-01-01', 51.12, 'Groceries', 'Credit card', 'His send we but spend will.')
# (314, '2024-01-11', 42.94, 'Groceries', 'Credit card', 'Leg until family.')
# (320, '2023-12-08', 43.92, 'Groceries', 'Credit card', 'Picture theory fly.')
# (321, '2024-01-27', 45.77, 'Groceries', 'Credit card', 'Herself act send moment main.')
# (324, '2023-12-16', 42.0, 'Groceries', 'Credit card', 'Sport let level institution fish relationship.')
# (330, '2024-01-09', 42.99, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (345, '2024-01-01', 49.66, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (348, '2024-01-26', 52.73, 'Groceries', 'Credit card', 'State call number exist.')
# (358, '2023-12-16', 49.39, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (366, '2024-01-10', 48.19, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (369, '2023-12-26', 41.88, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (377, '2024-01-11', 53.6, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (383, '2024-01-07', 54.4, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (398, '2024-01-12', 47.3, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (404, '2023-12-03', 42.36, 'Groceries', 'Credit card', 'Policy mean gas.')
# (414, '2024-01-28', 42.69, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (417, '2023-12-18', 58.55, 'Groceries', 'Credit card', 'Approach buy behavior consumer reveal.')
# (420, '2023-12-18', 57.49, 'Groceries', 'Credit card', 'Mind more government fish.')
# (421, '2024-01-07', 49.57, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (443, '2024-01-05', 56.88, 'Groceries', 'Credit card', 'Foot what next.')
# (445, '2023-12-07', 43.11, 'Groceries', 'Credit card', 'Wait say movie.')
# (446, '2023-12-22', 43.59, 'Groceries', 'Credit card', 'Prove board economy.')
# (447, '2024-01-27', 44.4, 'Groceries', 'Credit card', 'Scene story mission spend.')
# (448, '2024-01-03', 54.74, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (453, '2023-12-28', 42.27, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (454, '2024-01-17', 44.89, 'Groceries', 'Credit card', 'Word like our.')
# (456, '2024-01-29', 50.57, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (461, '2023-12-16', 42.98, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (464, '2023-12-02', 55.88, 'Groceries', 'Credit card', 'None respond off here two.')
# (466, '2023-12-31', 58.45, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (467, '2024-01-26', 47.05, 'Groceries', 'Credit card', 'Trouble billion would than well early.')
# (469, '2024-01-23', 43.04, 'Groceries', 'Credit card', 'Rate same born.')
# (474, '2023-12-29', 45.33, 'Groceries', 'Credit card', 'Either smile whose.')
# (476, '2024-01-22', 48.42, 'Groceries', 'Credit card', 'Green somebody market.')
# (482, '2024-01-14', 45.91, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (492, '2023-12-10', 44.62, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (494, '2023-12-20', 48.14, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (495, '2024-01-13', 42.07, 'Groceries', 'Credit card', 'Cultural fine teach bring best both.')
# (512, '2023-12-20', 40.79, 'Groceries', 'Credit card', 'Democratic for from pick.')
# (516, '2024-01-18', 51.9, 'Groceries', 'Credit card', 'Give job city group you response.')
# (520, '2024-01-14', 55.84, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (527, '2024-01-16', 56.62, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (534, '2024-01-07', 52.42, 'Groceries', 'Credit card', 'Sign ok money.')
# (545, '2023-12-18', 55.53, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (552, '2023-12-05', 50.96, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (553, '2024-01-01', 50.23, 'Groceries', 'Credit card', 'Possible recent range position value.')
# (568, '2024-01-22', 49.75, 'Groceries', 'Credit card', 'Little me they letter third great.')
# (579, '2023-12-07', 51.96, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (584, '2024-01-10', 40.66, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (588, '2023-12-24', 42.44, 'Groceries', 'Credit card', 'Life these case.')
# (589, '2023-12-11', 41.34, 'Groceries', 'Credit card', 'Yard board fund term board surface.')
# (601, '2023-12-13', 57.1, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (602, '2024-01-16', 55.8, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (609, '2024-01-21', 56.68, 'Groceries', 'Credit card', 'Early who tell them west authority.')
# (620, '2023-12-18', 58.42, 'Groceries', 'Credit card', 'Exactly number budget heavy understand say.')
# (625, '2024-01-31', 43.84, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (626, '2023-12-17', 41.86, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (630, '2023-12-16', 57.19, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (631, '2023-12-27', 44.62, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (633, '2023-12-05', 40.18, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (637, '2024-01-22', 46.36, 'Groceries', 'Credit card', 'Range coach memory wide hit.')
# (638, '2023-12-16', 48.59, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (639, '2024-01-04', 52.71, 'Groceries', 'Credit card', 'Wife investment trip.')
# (641, '2024-01-27', 52.79, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (644, '2023-12-23', 51.02, 'Groceries', 'Credit card', 'Skill remember book public.')
# (646, '2023-12-16', 44.77, 'Groceries', 'Credit card', 'Rich first summer.')
# (649, '2023-12-10', 40.4, 'Groceries', 'Credit card', 'Space cultural discussion administration three.')
# (650, '2024-01-30', 44.79, 'Groceries', 'Credit card', 'Individual stuff suffer.')
# (659, '2023-12-20', 53.57, 'Groceries', 'Credit card', 'Tell young star item.')
# (661, '2024-01-29', 54.8, 'Groceries', 'Credit card', 'It open center final management.')
# (665, '2024-01-29', 42.37, 'Groceries', 'Credit card', 'One adult of body measure.')
# (672, '2024-01-21', 43.75, 'Groceries', 'Credit card', 'Rule career general cultural school newspaper.')
# (673, '2024-01-21', 47.21, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (680, '2024-01-05', 47.52, 'Groceries', 'Credit card', 'Stay person law move serve.')
# (685, '2024-01-31', 45.7, 'Groceries', 'Credit card', 'Decide poor example.')
# (691, '2023-12-11', 46.82, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (699, '2024-01-05', 59.66, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (702, '2024-01-10', 54.56, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (704, '2024-01-30', 46.97, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (706, '2024-01-07', 50.92, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (711, '2023-12-26', 45.82, 'Groceries', 'Credit card', 'Effort director staff free.')
# (719, '2023-12-21', 42.31, 'Groceries', 'Credit card', 'Among development style.')
# (720, '2024-01-03', 45.47, 'Groceries', 'Credit card', 'Style head kind report hot.')
# (723, '2024-01-06', 57.96, 'Groceries', 'Credit card', 'Family account reality building build discussion.')
# (732, '2024-01-27', 45.07, 'Groceries', 'Credit card', 'Population military inside product he all.')
# (742, '2023-12-18', 45.0, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (743, '2024-01-02', 41.79, 'Groceries', 'Credit card', 'Decide watch important wife tell group.')
# (748, '2024-01-19', 44.08, 'Groceries', 'Credit card', 'Eight produce than himself.')
# (756, '2023-12-05', 47.91, 'Groceries', 'Credit card', 'Record field move sense option.')
# (758, '2024-01-07', 40.61, 'Groceries', 'Credit card', 'Task moment shake yourself national.')
# (760, '2023-12-23', 54.09, 'Groceries', 'Credit card', 'Project send mind.')
# (769, '2023-12-12', 51.11, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (775, '2023-12-15', 47.22, 'Groceries', 'Credit card', 'Rock ok worry whole answer.')
# (776, '2024-01-07', 40.08, 'Groceries', 'Credit card', 'Admit attorney back oil.')
# (786, '2023-12-13', 54.47, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (794, '2024-01-30', 54.61, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (802, '2023-12-20', 47.03, 'Groceries', 'Credit card', 'This purpose information interest his interview.')
# (807, '2024-01-02', 55.24, 'Groceries', 'Credit card', 'Strategy west particularly understand around.')
# (818, '2024-01-19', 44.84, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (824, '2023-12-29', 44.59, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (836, '2024-01-17', 44.46, 'Groceries', 'Credit card', 'Toward radio send.')
# (837, '2024-01-05', 40.96, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (838, '2024-01-11', 58.45, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (842, '2023-12-06', 53.78, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (847, '2024-01-23', 51.94, 'Groceries', 'Credit card', 'Soon ability concern.')
# (848, '2023-12-07', 43.98, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (849, '2024-01-10', 54.17, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (850, '2023-12-05', 43.48, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (852, '2024-01-31', 51.02, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (856, '2023-12-25', 44.63, 'Groceries', 'Credit card', 'Mind way decide Mr.')
# (857, '2023-12-18', 44.03, 'Groceries', 'Credit card', 'After direction really.')
# (869, '2023-12-21', 48.44, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (878, '2024-01-04', 40.27, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (885, '2024-01-05', 45.83, 'Groceries', 'Credit card', 'Treat responsibility beat.')
# (887, '2023-12-22', 48.13, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (892, '2024-01-05', 54.87, 'Groceries', 'Credit card', 'I add guy large.')
# (894, '2023-12-25', 45.87, 'Groceries', 'Credit card', 'Quickly her continue.')
# (897, '2024-01-10', 56.67, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (898, '2024-01-18', 56.44, 'Groceries', 'Credit card', 'Moment simple wear.')
# (901, '2024-01-30', 51.25, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (911, '2023-12-15', 40.28, 'Groceries', 'Credit card', 'Arrive remain bar address yeah event.')
# (913, '2023-12-19', 42.75, 'Groceries', 'Credit card', 'Operation international level.')
# (916, '2023-12-13', 52.58, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (917, '2023-12-05', 42.85, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (920, '2024-01-11', 44.32, 'Groceries', 'Credit card', 'Expert statement physical energy official series job.')
# (927, '2024-01-21', 58.77, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (933, '2024-01-26', 42.45, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (936, '2023-12-17', 51.4, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (943, '2023-12-29', 54.99, 'Groceries', 'Credit card', 'Employee recognize see.')
# (950, '2024-01-16', 48.89, 'Groceries', 'Credit card', 'Sister respond PM economy democratic detail.')
# (952, '2024-01-25', 42.17, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (964, '2023-12-29', 42.71, 'Groceries', 'Credit card', 'Theory ask just admit religious little.')
# (966, '2024-01-21', 50.35, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (967, '2023-12-06', 44.11, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (968, '2024-01-26', 46.76, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (978, '2024-01-15', 40.29, 'Groceries', 'Credit card', 'Away car ever know case.')
# (979, '2024-01-28', 48.05, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (981, '2023-12-06', 45.85, 'Groceries', 'Credit card', 'Oil new purpose every say.')
# (989, '2023-12-20', 53.88, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (993, '2023-12-02', 52.07, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (994, '2023-12-27', 50.12, 'Groceries', 'Credit card', 'Fruits and vegetables')
# (995, '2023-12-11', 41.88, 'Groceries', 'Credit card', 'Fruits and vegetables')

# %% [markdown]
# ### 3. Sum of Expenses by Category

# %%
cursor.execute("SELECT category, SUM(amount) AS total FROM expense GROUP BY category")
rows=cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Entertainment', 5804.400000000002)
# ('Groceries', 10219.86)
# ('Health care', 14121.379999999994)
# ('Transport', 23140.490000000016)
# ('Utilities', 43379.28)

# %% [markdown]
# ## Advanced Queries
#   ### 4. Find Top Spending Categories

# %%
cursor.execute("SELECT category, SUM(amount) AS total FROM expense GROUP BY category ORDER BY total DESC LIMIT 5")
rows=cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Utilities', 43379.28)
# ('Transport', 23140.490000000016)
# ('Health care', 14121.379999999994)
# ('Groceries', 10219.86)
# ('Entertainment', 5804.400000000002)

# %% [markdown]
# ### 5. Monthly Expense Breakdown

# %%
cursor.execute("""
SELECT strftime ('%Y-%m', date) AS month, SUM(amount) AS total
FROM expense
GROUP BY month
ORDER BY month
""")
rows=cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('2023-12', 45468.60999999997)
# ('2024-01', 47550.28000000002)
# ('2024-02', 3646.52)

# %% [markdown]
# # Analyze Data with Python

# %%
#Query data into pandas dataframe
df=pd.read_sql_query("SELECT * FROM expense", connection)

#Close the connection
connection.close()

#Display first 5 rows
df.head()
# Out:
#    id        date  amount     category payment_method  \
# 0   1  2023-12-27  191.16    Utilities  Bank transfer
# 1   2  2024-01-21  126.78    Transport     Dedit card
# 2   3  2024-01-24  117.58    Transport     Dedit card
# 3   4  2024-01-24   82.49  Health care    Credit card
# 4   5  2024-02-02   83.73  Health care    Credit card
#
#                                      description
# 0  Although sometimes tell current should agree.
# 1                          Give senior for seat.
# 2                               Monthly bus pass
# 3    Early pull himself street form real course.
# 4                                 Pharmacy visit

# %% [markdown]
# ## Perform Analysis
# ### 1. Total Expenses by Category

# %%
category_totals=df.groupby('category')['amount'].sum()
print(category_totals)
# Out:
# category
# Entertainment     5804.40
# Groceries        10219.86
# Health care      14121.38
# Transport        23140.49
# Utilities        43379.28
# Name: amount, dtype: float64

# %% [markdown]
# ### 2. Monthy Trends

# %%
df['month']=pd.to_datetime(df['date']).dt.to_period('M')
monthly_totals=df.groupby('month')['amount'].sum()
print(monthly_totals)
# Out:
# month
# 2023-12    45468.61
# 2024-01    47550.28
# 2024-02     3646.52
# Freq: M, Name: amount, dtype: float64

# %% [markdown]
# # Visualize the Data

# %% [markdown]
# ### 1. Bar Chart of Total Expenses by Category

# %%
category_totals.plot(kind='bar', title='Total Expenses by Category', ylabel='Amount')
plt.show()

# %% [markdown]
# ### 2. Line Chart for Monthy Trends

# %%
monthly_totals.plot(kind='line', title='Monthly Expense Trend', ylabel='Amount', xlabel='Month')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 3. Pie Chart of Category Distribution

# %%
category_totals.plot(kind='pie', title='Expense Distribution by Category', autopct='%1.1f%%')
plt.ylabel('')    #Hides the default y-axis label
plt.show()
